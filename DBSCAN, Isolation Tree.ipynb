# %%
### Week 10-1: Unsupervised Learning Part 3: Coding exercise

## Exercise 1

from sklearn import datasets
iris = datasets.load_iris()
X = iris.data[:,:2]

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=0.2, min_samples = 5)
labels = dbscan.fit_predict(X)

from matplotlib import pyplot
pyplot.scatter(X[:,0], X[:,1], c=labels, cmap='rainbow')
# Out:
# /Users/chpyo/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
## Exercise 2

from sklearn.ensemble import IsolationForest
iforest = IsolationForest(n_estimators=100, contamination=.02)
pred = iforest.fit_predict(X)

from numpy import where
anom_index = where(pred==-1)
values = X[anom_index]

pyplot.scatter(X[:,0], X[:,1])
pyplot.scatter(values[:,0], values[:,1], color='r')
